# %% [markdown]
# ## Existence Of Node Clusters

# %% [markdown]
# Here we demonstrate that in random forest that has been trained on some set of data, the nodes can be reasonably organized into clusters.
#
# First, we must train or load a forest:

# %%
import numpy as np
import matplotlib.pyplot as plt
import scanpy as sc
from scipy.stats import multivariate_normal

import sys
# sys.path.append('/localscratch/bbrener1/rusty_forest_v3/src')
sys.path.append('../src/python')
import tree_reader as tr 
import lumberjack

iris = np.loadtxt("../data/iris/iris.tsv")
iris_features = np.loadtxt("../data/iris/header.txt",dtype=str)

iris_forest = lumberjack.fit(
    iris,
    trees=100,
    ifs=3,
    ofs=3,
    ss=100,
    leaves=10,
    depth=4,
    dispersion_mode='ssme',
    sfr=0,
    norm='l2',
    standardize='true',
    reduce_input='false',
    reduce_output='false',
)

sphere = multivariate_normal(np.zeros(4)).rvs(size=150)

spherical_forest = lumberjack.fit(
    sphere,
    trees=100,
    ifs=3,
    ofs=3,
    ss=100,
    leaves=10,
    depth=4,
    dispersion_mode='ssme',
    sfr=0,
    standardize='true',
    reduce_input='false',
    reduce_output='false',
)
# Out:
# Setting context
# Input:(150, 4)
# Output:(150, 4)
# Generating trees
# Running /Users/bbrener1/battle/rf_5/target/release/rf_5
# Command: /Users/bbrener1/battle/rf_5/target/release/rf_5 -ic /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/input.counts -oc /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/output.counts -o /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp -auto -ifh /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.ifh -ofh /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.ofh -trees 100 -ifs 3 -ofs 3 -ss 100 -leaves 10 -depth 4 -dispersion_mode ssme -sfr 0 -norm l2 -standardize true -reduce_input false -reduce_output false
# Read parameters
#
# 5.1 0
# 100
# ===========
# 150,4
#
# 5.1 0
# 100
# ===========
# 150,4
# Reading header: /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.ifh
# Read 4 lines
# Reading header: /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.ofh
# Read 4 lines
# Computing tree 6
# Computing tree 1
# Computing tree 87
# Computing tree 50
# Computing tree 0
# Computing tree 75
# Computing tree 7
# Computing tree 12
# Computing tree 3
# Computing tree 9
# Computing tree 25
# Computing tree 37
# Computing tree 51
# Computing tree 4
# Computing tree 38
# Computing tree 10
# Computing tree 5
# Computing tree 76
# Computing tree 8
# Computing tree 26
# Computing tree 13
# Computing tree 81
# Computing tree 88
# Computing tree 52
# Computing tree 2
# Computing tree 82
# Computing tree 77
# Computing tree 43
# Computing tree 93
# Computing tree 40
# Computing tree 11
# Computing tree 39
# Computing tree 89
# Computing tree 78
# Computing tree 27
# Computing tree 14
# Computing tree 62
# Computing tree 83
# Computing tree 53
# Computing tree 90
# Computing tree 79
# Computing tree 44
# Computing tree 41
# Computing tree 28
# Computing tree 94
# Computing tree 46
# Computing tree 54
# Computing tree 18
# Computing tree 15
# Computing tree 63
# Computing tree 91
# Computing tree 95
# Computing tree 80
# Computing tree 45
# Computing tree 84
# Computing tree 47
# Computing tree 55
# Computing tree 42
# Computing tree 64
# Computing tree 29
# Computing tree 19
# Computing tree 16
# Computing tree 56
# Computing tree 96
# Computing tree 30
# Computing tree 31
# Computing tree 68
# Computing tree 92
# Computing tree 85
# Computing tree 65
# Computing tree 48
# Computing tree 17
# Computing tree 20
# Computing tree 97
# Computing tree 21
# Computing tree 49
# Computing tree 32
# Computing tree 98
# Computing tree 57
# Computing tree 69
# Computing tree 34
# Computing tree 66
# Computing tree 86
# Computing tree 59
# Computing tree 33
# Computing tree 22
# Computing tree 60
# Computing tree 67
# Computing tree 35
# Computing tree 61
# Computing tree 99
# Computing tree 71
# Computing tree 36
# Computing tree 58
# Computing tree 70
# Computing tree 23
# Computing tree 73
# Computing tree 74
# Computing tree 72
# Computing tree 24
#
#
# Rust observes: /Users/bbrener1/battle/rf_5/target/release/rf_5
#
# CHECK TRUTH
# /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y
# ['tmp.tree_42.compact', 'tmp.tree_52.compact', 'tmp.tree_3.compact', 'tmp.tree_99.compact', 'tmp.tree_89.compact', 'tmp.tree_20.compact', 'tmp.tree_30.compact', 'tmp.tree_16.compact', 'input.counts', 'tmp.tree_64.compact', 'tmp.tree_74.compact', 'tmp.tree_80.compact', 'tmp.tree_90.compact', 'tmp.tree_39.compact', 'tmp.tree_29.compact', 'tmp.tree_17.compact', 'tmp.tree_75.compact', 'tmp.tree_65.compact', 'tmp.tree_28.compact', 'tmp.tree_38.compact', 'tmp.tree_91.compact', 'tmp.tree_81.compact', 'tmp.tree_2.compact', 'tmp.tree_53.compact', 'tmp.tree_43.compact', 'tmp.tree_31.compact', 'tmp.tree_21.compact', 'tmp.tree_88.compact', 'tmp.tree_98.compact', 'tmp.tree_67.compact', 'tmp.tree_77.compact', 'tmp.tree_15.compact', 'tmp.tree_9.compact', 'tmp.tree_58.compact', 'tmp.tree_48.compact', 'tmp.tree_83.compact', 'tmp.tree_93.compact', 'tmp.ifh', 'tmp.tree_23.compact', 'tmp.tree_33.compact', 'tmp.tree_0.compact', 'tmp.tree_41.compact', 'tmp.tree_51.compact', 'output.counts', 'tmp.tree_32.compact', 'tmp.tree_22.compact', 'tmp.tree_50.compact', 'tmp.tree_40.compact', 'tmp.tree_1.compact', 'tmp.tree_76.compact', 'tmp.tree_66.compact', 'tmp.tree_14.compact', 'tmp.tree_49.compact', 'tmp.tree_59.compact', 'tmp.tree_8.compact', 'tmp.tree_92.compact', 'tmp.tree_82.compact', 'tmp.tree_87.compact', 'tmp.tree_97.compact', 'tmp.tree_63.compact', 'tmp.tree_73.compact', 'tmp.tree_11.compact', 'tmp.tree_27.compact', 'tmp.tree_37.compact', 'tmp.tree_45.compact', 'tmp.tree_55.compact', 'tmp.tree_4.compact', 'tmp.tree_18.compact', 'tmp.tree_36.compact', 'tmp.tree_26.compact', 'tmp.tree_5.compact', 'tmp.tree_54.compact', 'tmp.tree_44.compact', 'tmp.tree_19.compact', 'tmp.tree_96.compact', 'tmp.tree_86.compact', 'tmp.tree_72.compact', 'tmp.tree_62.compact', 'tmp.tree_10.compact', 'tmp.tree_7.compact', 'tmp.tree_46.compact', 'tmp.tree_56.compact', 'tmp.tree_24.compact', 'tmp.tree_34.compact', 'tmp.ofh', 'tmp.tree_79.compact', 'tmp.tree_69.compact', 'tmp.tree_84.compact', 'tmp.tree_94.compact', 'tmp.tree_12.compact', 'tmp.tree_60.compact', 'tmp.tree_70.compact', 'tmp.tree_95.compact', 'tmp.tree_85.compact', 'tmp.tree_13.compact', 'tmp.tree_71.compact', 'tmp.tree_61.compact', 'tmp.tree_57.compact', 'tmp.tree_47.compact', 'tmp.tree_6.compact', 'tmp.tree_35.compact', 'tmp.tree_25.compact', 'tmp.tree_68.compact', 'tmp.tree_78.compact']
# Generating trees
# CHECK OUTPUT
# ['tmp.tree_42.compact', 'tmp.tree_52.compact', 'tmp.tree_3.compact', 'tmp.tree_99.compact', 'tmp.tree_89.compact', 'tmp.tree_20.compact', 'tmp.tree_30.compact', 'tmp.tree_16.compact', 'input.counts', 'tmp.tree_64.compact', 'tmp.tree_74.compact', 'tmp.tree_80.compact', 'tmp.tree_90.compact', 'tmp.tree_39.compact', 'tmp.tree_29.compact', 'tmp.tree_17.compact', 'tmp.tree_75.compact', 'tmp.tree_65.compact', 'tmp.tree_28.compact', 'tmp.tree_38.compact', 'tmp.tree_91.compact', 'tmp.tree_81.compact', 'tmp.tree_2.compact', 'tmp.tree_53.compact', 'tmp.tree_43.compact', 'tmp.tree_31.compact', 'tmp.tree_21.compact', 'tmp.tree_88.compact', 'tmp.tree_98.compact', 'tmp.tree_67.compact', 'tmp.tree_77.compact', 'tmp.tree_15.compact', 'tmp.tree_9.compact', 'tmp.tree_58.compact', 'tmp.tree_48.compact', 'tmp.tree_83.compact', 'tmp.tree_93.compact', 'tmp.ifh', 'tmp.tree_23.compact', 'tmp.tree_33.compact', 'tmp.tree_0.compact', 'tmp.tree_41.compact', 'tmp.tree_51.compact', 'output.counts', 'tmp.tree_32.compact', 'tmp.tree_22.compact', 'tmp.tree_50.compact', 'tmp.tree_40.compact', 'tmp.tree_1.compact', 'tmp.tree_76.compact', 'tmp.tree_66.compact', 'tmp.tree_14.compact', 'tmp.tree_49.compact', 'tmp.tree_59.compact', 'tmp.tree_8.compact', 'tmp.tree_92.compact', 'tmp.tree_82.compact', 'tmp.tree_87.compact', 'tmp.tree_97.compact', 'tmp.tree_63.compact', 'tmp.tree_73.compact', 'tmp.tree_11.compact', 'tmp.tree_27.compact', 'tmp.tree_37.compact', 'tmp.tree_45.compact', 'tmp.tree_55.compact', 'tmp.tree_4.compact', 'tmp.tree_18.compact', 'tmp.tree_36.compact', 'tmp.tree_26.compact', 'tmp.tree_5.compact', 'tmp.tree_54.compact', 'tmp.tree_44.compact', 'tmp.tree_19.compact', 'tmp.tree_96.compact', 'tmp.tree_86.compact', 'tmp.tree_72.compact', 'tmp.tree_62.compact', 'tmp.tree_10.compact', 'tmp.tree_7.compact', 'tmp.tree_46.compact', 'tmp.tree_56.compact', 'tmp.tree_24.compact', 'tmp.tree_34.compact', 'tmp.ofh', 'tmp.tree_79.compact', 'tmp.tree_69.compact', 'tmp.tree_84.compact', 'tmp.tree_94.compact', 'tmp.tree_12.compact', 'tmp.tree_60.compact', 'tmp.tree_70.compact', 'tmp.tree_95.compact', 'tmp.tree_85.compact', 'tmp.tree_13.compact', 'tmp.tree_71.compact', 'tmp.tree_61.compact', 'tmp.tree_57.compact', 'tmp.tree_47.compact', 'tmp.tree_6.compact', 'tmp.tree_35.compact', 'tmp.tree_25.compact', 'tmp.tree_68.compact', 'tmp.tree_78.compact']
# Looking for clusters:/var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.clusters
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_0.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_1.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_10.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_11.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_12.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_13.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_14.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_15.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_16.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_17.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_18.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_19.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_2.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_20.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_21.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_22.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_23.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_24.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_25.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_26.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_27.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_28.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_29.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_3.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_30.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_31.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_32.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_33.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_34.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_35.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_36.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_37.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_38.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_39.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_4.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_40.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_41.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_42.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_43.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_44.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_45.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_46.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_47.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_48.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_49.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_5.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_50.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_51.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_52.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_53.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_54.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_55.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_56.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_57.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_58.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_59.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_6.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_60.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_61.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_62.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_63.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_64.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_65.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_66.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_67.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_68.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_69.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_7.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_70.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_71.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_72.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_73.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_74.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_75.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_76.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_77.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_78.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_79.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_8.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_80.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_81.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_82.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_83.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_84.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_85.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_86.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_87.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_88.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_89.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_9.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_90.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_91.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_92.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_93.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_94.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_95.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_96.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_97.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_98.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmp9ne65y7y/tmp.tree_99.compact
# Setting context
# Input:(150, 4)
# Output:(150, 4)
# Generating trees
# Running /Users/bbrener1/battle/rf_5/target/release/rf_5
# Command: /Users/bbrener1/battle/rf_5/target/release/rf_5 -ic /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/input.counts -oc /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/output.counts -o /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp -auto -ifh /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.ifh -ofh /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.ofh -trees 100 -ifs 3 -ofs 3 -ss 100 -leaves 10 -depth 4 -dispersion_mode ssme -sfr 0 -standardize true -reduce_input false -reduce_output false
# Read parameters
#
# -0.3656375033756113 0
# 100
# ===========
# 150,4
#
# -0.3656375033756113 0
# 100
# ===========
# 150,4
# Reading header: /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.ifh
# Read 4 lines
# Reading header: /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.ofh
# Read 4 lines
# Computing tree 12
# Computing tree 6
# Computing tree 9
# Computing tree 3
# Computing tree 0
# Computing tree 21
# Computing tree 1
# Computing tree 50
# Computing tree 19
# Computing tree 18
# Computing tree 25
# Computing tree 4
# Computing tree 20
# Computing tree 23
# Computing tree 15
# Computing tree 22
# Computing tree 5
# Computing tree 10
# Computing tree 26
# Computing tree 51
# Computing tree 7
# Computing tree 13
# Computing tree 11
# Computing tree 2
# Computing tree 8
# Computing tree 24
# Computing tree 14
# Computing tree 16
# Computing tree 37
# Computing tree 31
# Computing tree 28
# Computing tree 52
# Computing tree 17
# Computing tree 27
# Computing tree 43
# Computing tree 75
# Computing tree 62
# Computing tree 46
# Computing tree 34
# Computing tree 40
# Computing tree 32
# Computing tree 29
# Computing tree 30
# Computing tree 38
# Computing tree 76
# Computing tree 53
# Computing tree 48
# Computing tree 47
# Computing tree 44
# Computing tree 63
# Computing tree 35
# Computing tree 33
# Computing tree 45
# Computing tree 41
# Computing tree 39
# Computing tree 42
# Computing tree 49
# Computing tree 87
# Computing tree 93
# Computing tree 90
# Computing tree 77
# Computing tree 68
# Computing tree 88
# Computing tree 64
# Computing tree 54
# Computing tree 81
# Computing tree 36
# Computing tree 71
# Computing tree 89
# Computing tree 78
# Computing tree 69
# Computing tree 70
# Computing tree 94
# Computing tree 82
# Computing tree 91
# Computing tree 79
# Computing tree 56
# Computing tree 65
# Computing tree 55
# Computing tree 66
# Computing tree 84
# Computing tree 96
# Computing tree 85
# Computing tree 95
# Computing tree 72
# Computing tree 80
# Computing tree 92
# Computing tree 83
# Computing tree 57
# Computing tree 98
# Computing tree 67
# Computing tree 97
# Computing tree 86
# Computing tree 73
# Computing tree 99
# Computing tree 59
# Computing tree 60
# Computing tree 58
# Computing tree 61
# Computing tree 74
#
#
# Rust observes: /Users/bbrener1/battle/rf_5/target/release/rf_5
#
# CHECK TRUTH
# /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p
# ['tmp.tree_42.compact', 'tmp.tree_52.compact', 'tmp.tree_3.compact', 'tmp.tree_99.compact', 'tmp.tree_89.compact', 'tmp.tree_20.compact', 'tmp.tree_30.compact', 'tmp.tree_16.compact', 'input.counts', 'tmp.tree_64.compact', 'tmp.tree_74.compact', 'tmp.tree_80.compact', 'tmp.tree_90.compact', 'tmp.tree_39.compact', 'tmp.tree_29.compact', 'tmp.tree_17.compact', 'tmp.tree_75.compact', 'tmp.tree_65.compact', 'tmp.tree_28.compact', 'tmp.tree_38.compact', 'tmp.tree_91.compact', 'tmp.tree_81.compact', 'tmp.tree_2.compact', 'tmp.tree_53.compact', 'tmp.tree_43.compact', 'tmp.tree_31.compact', 'tmp.tree_21.compact', 'tmp.tree_88.compact', 'tmp.tree_98.compact', 'tmp.tree_67.compact', 'tmp.tree_77.compact', 'tmp.tree_15.compact', 'tmp.tree_9.compact', 'tmp.tree_58.compact', 'tmp.tree_48.compact', 'tmp.tree_83.compact', 'tmp.tree_93.compact', 'tmp.ifh', 'tmp.tree_23.compact', 'tmp.tree_33.compact', 'tmp.tree_0.compact', 'tmp.tree_41.compact', 'tmp.tree_51.compact', 'output.counts', 'tmp.tree_32.compact', 'tmp.tree_22.compact', 'tmp.tree_50.compact', 'tmp.tree_40.compact', 'tmp.tree_1.compact', 'tmp.tree_76.compact', 'tmp.tree_66.compact', 'tmp.tree_14.compact', 'tmp.tree_49.compact', 'tmp.tree_59.compact', 'tmp.tree_8.compact', 'tmp.tree_92.compact', 'tmp.tree_82.compact', 'tmp.tree_87.compact', 'tmp.tree_97.compact', 'tmp.tree_63.compact', 'tmp.tree_73.compact', 'tmp.tree_11.compact', 'tmp.tree_27.compact', 'tmp.tree_37.compact', 'tmp.tree_45.compact', 'tmp.tree_55.compact', 'tmp.tree_4.compact', 'tmp.tree_18.compact', 'tmp.tree_36.compact', 'tmp.tree_26.compact', 'tmp.tree_5.compact', 'tmp.tree_54.compact', 'tmp.tree_44.compact', 'tmp.tree_19.compact', 'tmp.tree_96.compact', 'tmp.tree_86.compact', 'tmp.tree_72.compact', 'tmp.tree_62.compact', 'tmp.tree_10.compact', 'tmp.tree_7.compact', 'tmp.tree_46.compact', 'tmp.tree_56.compact', 'tmp.tree_24.compact', 'tmp.tree_34.compact', 'tmp.ofh', 'tmp.tree_79.compact', 'tmp.tree_69.compact', 'tmp.tree_84.compact', 'tmp.tree_94.compact', 'tmp.tree_12.compact', 'tmp.tree_60.compact', 'tmp.tree_70.compact', 'tmp.tree_95.compact', 'tmp.tree_85.compact', 'tmp.tree_13.compact', 'tmp.tree_71.compact', 'tmp.tree_61.compact', 'tmp.tree_57.compact', 'tmp.tree_47.compact', 'tmp.tree_6.compact', 'tmp.tree_35.compact', 'tmp.tree_25.compact', 'tmp.tree_68.compact', 'tmp.tree_78.compact']
# Generating trees
# CHECK OUTPUT
# ['tmp.tree_42.compact', 'tmp.tree_52.compact', 'tmp.tree_3.compact', 'tmp.tree_99.compact', 'tmp.tree_89.compact', 'tmp.tree_20.compact', 'tmp.tree_30.compact', 'tmp.tree_16.compact', 'input.counts', 'tmp.tree_64.compact', 'tmp.tree_74.compact', 'tmp.tree_80.compact', 'tmp.tree_90.compact', 'tmp.tree_39.compact', 'tmp.tree_29.compact', 'tmp.tree_17.compact', 'tmp.tree_75.compact', 'tmp.tree_65.compact', 'tmp.tree_28.compact', 'tmp.tree_38.compact', 'tmp.tree_91.compact', 'tmp.tree_81.compact', 'tmp.tree_2.compact', 'tmp.tree_53.compact', 'tmp.tree_43.compact', 'tmp.tree_31.compact', 'tmp.tree_21.compact', 'tmp.tree_88.compact', 'tmp.tree_98.compact', 'tmp.tree_67.compact', 'tmp.tree_77.compact', 'tmp.tree_15.compact', 'tmp.tree_9.compact', 'tmp.tree_58.compact', 'tmp.tree_48.compact', 'tmp.tree_83.compact', 'tmp.tree_93.compact', 'tmp.ifh', 'tmp.tree_23.compact', 'tmp.tree_33.compact', 'tmp.tree_0.compact', 'tmp.tree_41.compact', 'tmp.tree_51.compact', 'output.counts', 'tmp.tree_32.compact', 'tmp.tree_22.compact', 'tmp.tree_50.compact', 'tmp.tree_40.compact', 'tmp.tree_1.compact', 'tmp.tree_76.compact', 'tmp.tree_66.compact', 'tmp.tree_14.compact', 'tmp.tree_49.compact', 'tmp.tree_59.compact', 'tmp.tree_8.compact', 'tmp.tree_92.compact', 'tmp.tree_82.compact', 'tmp.tree_87.compact', 'tmp.tree_97.compact', 'tmp.tree_63.compact', 'tmp.tree_73.compact', 'tmp.tree_11.compact', 'tmp.tree_27.compact', 'tmp.tree_37.compact', 'tmp.tree_45.compact', 'tmp.tree_55.compact', 'tmp.tree_4.compact', 'tmp.tree_18.compact', 'tmp.tree_36.compact', 'tmp.tree_26.compact', 'tmp.tree_5.compact', 'tmp.tree_54.compact', 'tmp.tree_44.compact', 'tmp.tree_19.compact', 'tmp.tree_96.compact', 'tmp.tree_86.compact', 'tmp.tree_72.compact', 'tmp.tree_62.compact', 'tmp.tree_10.compact', 'tmp.tree_7.compact', 'tmp.tree_46.compact', 'tmp.tree_56.compact', 'tmp.tree_24.compact', 'tmp.tree_34.compact', 'tmp.ofh', 'tmp.tree_79.compact', 'tmp.tree_69.compact', 'tmp.tree_84.compact', 'tmp.tree_94.compact', 'tmp.tree_12.compact', 'tmp.tree_60.compact', 'tmp.tree_70.compact', 'tmp.tree_95.compact', 'tmp.tree_85.compact', 'tmp.tree_13.compact', 'tmp.tree_71.compact', 'tmp.tree_61.compact', 'tmp.tree_57.compact', 'tmp.tree_47.compact', 'tmp.tree_6.compact', 'tmp.tree_35.compact', 'tmp.tree_25.compact', 'tmp.tree_68.compact', 'tmp.tree_78.compact']
# Looking for clusters:/var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.clusters
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_0.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_1.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_10.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_11.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_12.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_13.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_14.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_15.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_16.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_17.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_18.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_19.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_2.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_20.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_21.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_22.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_23.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_24.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_25.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_26.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_27.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_28.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_29.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_3.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_30.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_31.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_32.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_33.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_34.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_35.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_36.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_37.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_38.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_39.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_4.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_40.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_41.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_42.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_43.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_44.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_45.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_46.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_47.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_48.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_49.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_5.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_50.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_51.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_52.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_53.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_54.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_55.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_56.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_57.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_58.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_59.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_6.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_60.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_61.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_62.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_63.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_64.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_65.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_66.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_67.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_68.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_69.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_7.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_70.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_71.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_72.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_73.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_74.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_75.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_76.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_77.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_78.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_79.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_8.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_80.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_81.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_82.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_83.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_84.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_85.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_86.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_87.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_88.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_89.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_9.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_90.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_91.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_92.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_93.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_94.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_95.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_96.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_97.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_98.compact
# Loading /var/folders/_k/81hqlgss0tbf2l0t7wm4t_200000gn/T/tmpk9kq5p5p/tmp.tree_99.compact

# %%
iris_class = np.loadtxt("../data/iris/class.txt",dtype='str')
iris_header = np.zeros(150,dtype=int)
iris_header[iris_class == "Iris-setosa"] = 0
iris_header[iris_class == "Iris-versicolor"] = 1
iris_header[iris_class == "Iris-virginica"] = 2

# %% [markdown]
# A Random Forest is a collection of decision trees, and a decision tree is a collection of individual decision points, commonly known as "Nodes"
#
# To understand Random Forests and Decision Trees, it is important to understand how Nodes work. Each individual node is a (very crappy) regressor, eg. each Node makess a prediction based on a rule like "If Gene 1 has expression > 10, Gene 2 will have expression < 5", or "If a house is < 5 miles from a school, it will cost > $100,000". A very important property of each node, however, is that it can also have children, which are other nodes. When a node makes a prediction like "If Gene 1 has expression > 10 then Gene 2 has expression < 5", it can pass all the samples for which Gene 1 is > 10 to one of its children, and all the samples for which Gene 1 < 10 to the other child. After that, each one of its children can make a different prediction, which results in compound rules.
#
# This is how a decision tree is formed. A decision tree with a depth of 2 might contain a rule like "If Gene 1 > 10 AND Gene 3 > 10, THEN Gene 2 and Gene 4 are both < 2, which would represent one of the "Leaf" nodes that it has. Leaf nodes are nodes with no children.
#
# Individual decision trees, then, are somewhat crappy predictors, but they're better than individual nodes. In order to improve the performance of decision trees, we can construct a Random Forest. To construct a random forest, we can train many decision trees on bootstraps of a dataset
#
# If many decision trees are combined and their predictions averaged together, you have a Random Forest, which is a pretty good kind of regressor.
#
# A practical demonstration might help:

# %%
iris_forest.reset_split_clusters()
iris_forest.interpret_splits(depth=3,mode='additive_mean',metric='cosine',relatives=True,k=10)


spherical_forest.reset_split_clusters()
spherical_forest.interpret_splits(depth=3,mode='additive_mean',metric='cosine',relatives=True,k=10)

# %% [markdown]
# So now that we know that random forests are collections of ordered nodes, we can examine a more interesting question: do certain nodes occur repeatedly in the forest, despite operating on bootstrapped samples?
#
# In order to examine this question first we must understand different ways of describing a node. I think generally there are three helpful ways of looking at a node:
#
# * **Node Sample Encoding**: A binary vector the length of the number of samples you are considering. 0 or false means the sample is absent from the node. A 1 or true means the sample is present in the node.
#
# * **Node Mean Encoding**: A float vector the length of the number of targets you are considering. Each value is the mean of the target values for all samples in this node. This is the node's prediction for samples that occur in it.
#
# * **Node Additive Encoding**: A float vector the length of the number of targets you are considering. Each value is THE DIFFERENCE between the mean value for that target in THIS NODE and the mean value for that target IN THE PARENT of this node. For root nodes, which have no parents, the additive encoding is simply th mean value across the entire dataset. (As if the mean of a hypothetical parent would have been 0). This encoding represents the marginal effect of each node.
#
# We should examine if there are any common patterns that appear if we encode many nodes from a forest using each of these representations:

# %%
# Here we plot the sample representations of nodes for the iris forest. 
# This generates a set of figures demonstrating the existence of node clusters

from sklearn.decomposition import PCA

sample_encoding = iris_forest.node_representation(iris_forest.nodes(depth=3,root=False),mode='sample')
sister_encoding = iris_forest.node_representation(iris_forest.nodes(depth=3,root=False),mode='sister')
reduced_sample = PCA(n_components=100).fit_transform(sample_encoding.T)
reduced_sister = PCA(n_components=100).fit_transform(sister_encoding.T)
# reduced_node = PCA(n_components=100).fit_transform(sample_encoding)
reduced_node = PCA(n_components=100).fit_transform(sister_encoding)

print(sample_encoding.shape)
print(reduced_sample.shape)
print(reduced_node.shape)

from scipy.cluster.hierarchy import linkage,dendrogram

sample_agglomeration = dendrogram(linkage(reduced_sample, metric='cosine', method='average'), no_plot=True)['leaves']
sister_agglomeration = dendrogram(linkage(reduced_sister, metric='cosine', method='average'), no_plot=True)['leaves']
node_agglomeration = dendrogram(linkage(reduced_node, metric='cosine', method='average'), no_plot=True)['leaves']

plt.figure()
plt.title("Iris Sample Presence in Node (Two-Way Agglomerated)")
plt.imshow(sample_encoding[node_agglomeration].T[sample_agglomeration].T,cmap='binary',aspect='auto',interpolation='none')
plt.xlabel("Samples")
plt.ylabel("Nodes")
plt.colorbar(label="Presence In Node")
plt.tight_layout()
plt.show()

plt.figure()
plt.title("Iris Sample Presence in Node (Two-Way Agglomerated)")
plt.imshow(sister_encoding[node_agglomeration].T[sister_agglomeration].T,cmap='bwr',aspect='auto',interpolation='none')
plt.xlabel("Samples")
plt.ylabel("Nodes")
plt.colorbar(label="Presence In Node")
plt.tight_layout()
plt.show()


plt.figure()
plt.title("Iris Sample Presence in Node (Agglomerated)")
plt.imshow(sample_encoding[node_agglomeration],cmap='binary',aspect='auto',interpolation='none')
plt.xlabel("Samples")
plt.ylabel("Nodes")
plt.colorbar(label="Presence In Node")
plt.tight_layout()
plt.show()

# And here we sort the nodes after they have been clustered (more on the clustering procedure in a bit)

node_cluster_sort = np.argsort([n.split_cluster for n in iris_forest.nodes(depth=3,root=False)])

plt.figure()
plt.title("Sample Presence in Node (Clustered by Gain)")
plt.imshow(sample_encoding[node_cluster_sort],cmap='binary',aspect='auto',interpolation='none')
plt.xlabel("Samples")
plt.ylabel("Nodes")
plt.colorbar(label="Presence In Node")
plt.tight_layout()
plt.show()

plt.figure(figsize=(4,1))
plt.imshow(np.array([iris_header,]),aspect='auto',interpolation='none',cmap='rainbow')
plt.xlabel("Iris Species")
plt.show()

# %%
# Here we plot the sample representations of nodes for the iris forest. 
# This generates a set of figures demonstrating the existence of node clusters

from sklearn.decomposition import PCA

sample_encoding = spherical_forest.node_representation(spherical_forest.nodes(depth=3,root=False),mode='sample')
sister_encoding = spherical_forest.node_representation(spherical_forest.nodes(depth=3,root=False),mode='sister')
reduced_sample = PCA(n_components=100).fit_transform(sample_encoding.T)
reduced_sister = PCA(n_components=100).fit_transform(sister_encoding.T)
# reduced_node = PCA(n_components=100).fit_transform(sample_encoding)
reduced_node = PCA(n_components=100).fit_transform(sister_encoding)

print(sample_encoding.shape)
print(reduced_sample.shape)
print(reduced_node.shape)

from scipy.cluster.hierarchy import linkage,dendrogram

sample_agglomeration = dendrogram(linkage(reduced_sample, metric='cosine', method='average'), no_plot=True)['leaves']
sister_agglomeration = dendrogram(linkage(reduced_sister, metric='cosine', method='average'), no_plot=True)['leaves']
node_agglomeration = dendrogram(linkage(reduced_node, metric='cosine', method='average'), no_plot=True)['leaves']
node_cluster_sort = np.argsort([n.split_cluster for n in spherical_forest.nodes(depth=3,root=False)])

plt.figure()
plt.title("Gaussian Noise Sample Presence in Node \n(Two-Way Agglomerated)")
plt.imshow(sample_encoding[node_agglomeration].T[sample_agglomeration].T,cmap='binary',aspect='auto',interpolation='none')
plt.xlabel("Samples")
plt.ylabel("Nodes")
plt.colorbar(label="Presence In Node")
plt.tight_layout()
plt.show()

plt.figure()
plt.title("Gaussian Noise Sample Presence in Node vs Sister \n(Two-Way Agglomerated)")
plt.imshow(sister_encoding[node_agglomeration].T[sister_agglomeration].T,cmap='bwr',aspect='auto',interpolation='none')
plt.xlabel("Samples")
plt.ylabel("Nodes")
plt.colorbar(label="Presence In Node")
plt.tight_layout()
plt.show()

# And here we sort the nodes after they have been clustered (more on the clustering procedure in a bit)


plt.figure()
plt.title("Gaussian Noise Sample Presence in Node (Clustered by Gain)")
plt.imshow(sample_encoding[node_cluster_sort].T[sample_agglomeration].T,cmap='binary',aspect='auto',interpolation='none')
plt.xlabel("Samples")
plt.ylabel("Nodes")
plt.colorbar(label="Presence In Node")
plt.tight_layout()
plt.show()

# %%
from sklearn.decomposition import PCA

sample_encoding = iris_forest.node_representation(iris_forest.nodes(depth=3,root=False),mode='sister')
reduced_sample = PCA(n_components=100).fit_transform(sample_encoding.T)
reduced_node = PCA(n_components=100).fit_transform(sample_encoding)

print(sample_encoding.shape)
print(reduced_sample.shape)
print(reduced_node.shape)

from scipy.cluster.hierarchy import linkage,dendrogram

sample_agglomeration = dendrogram(linkage(reduced_sample, metric='cosine', method='average'), no_plot=True)['leaves']
node_agglomeration = dendrogram(linkage(reduced_node, metric='cosine', method='average'), no_plot=True)['leaves']

node_cluster_sort = np.argsort([n.split_cluster for n in iris_forest.nodes(depth=3,root=False)])

plt.figure()
plt.title("Iris Sample Presence in Node vs Sister (Two-Way Agglomerated)")
plt.imshow(sample_encoding[node_agglomeration].T[sample_agglomeration].T,cmap='bwr',aspect='auto',interpolation='none')
plt.xlabel("Samples")
plt.ylabel("Nodes")
plt.colorbar()
plt.tight_layout()
plt.show()

plt.figure()
plt.title("Iris Sample Presence in Node vs Sister \n(Clustered By Gain)")
plt.imshow(sample_encoding[node_cluster_sort].T[sample_agglomeration].T,cmap='bwr',aspect='auto',interpolation='none')
plt.xlabel("Samples")
plt.ylabel("Nodes")
plt.colorbar()
plt.tight_layout()
plt.show()

# %%
# Here we plot the construct and agglomerate the additive gain representation 


sample_encoding = iris_forest.node_representation(iris_forest.nodes(depth=3,root=False),mode='sample')
reduced_sample = PCA(n_components=100).fit_transform(sample_encoding.T)
reduced_node = PCA(n_components=100).fit_transform(sample_encoding)

sample_agglomeration = dendrogram(linkage(reduced_sample, metric='cosine', method='average'), no_plot=True)['leaves']
node_agglomeration = dendrogram(linkage(reduced_node, metric='cosine', method='average'), no_plot=True)['leaves']

feature_encoding = iris_forest.node_representation(iris_forest.nodes(depth=3,root=False),mode='additive_mean')
reduced_feature = PCA().fit_transform(feature_encoding.T)
reduced_node = PCA().fit_transform(feature_encoding)

feature_agglomeration = dendrogram(linkage(reduced_feature, metric='cosine', method='average'), no_plot=True)['leaves']
node_agglomeration = dendrogram(linkage(reduced_node, metric='cosine', method='average'), no_plot=True)['leaves']

node_cluster_sort = np.argsort([n.split_cluster for n in iris_forest.nodes(depth=3,root=False)])

# %%
# Here we plot the additive gain representation 

# print(feature_encoding.shape)

# plt.figure()
# plt.title("Target Gain in Node (Double-Agglomerated)")
# plt.imshow(feature_encoding[node_agglomeration].T[feature_agglomeration].T,cmap='bwr',interpolation='none',aspect='auto',vmin=-2,vmax=2)
# plt.xlabel("Features")
# plt.ylabel("Nodes")
# plt.colorbar(label="Parent Target Mean - Node Target Mean")
# plt.tight_layout()
# plt.show()


plt.figure(figsize=(5,3))
plt.title("Target Gain in Node (Clustered)")
plt.imshow(feature_encoding[node_cluster_sort].T[feature_agglomeration].T,cmap='bwr',interpolation='none',aspect='auto',vmin=-2,vmax=2)
plt.xlabel("Features")
plt.ylabel("Nodes")
plt.colorbar(label="Parent Mean - Node Mean")
plt.xticks(np.arange(4),labels=iris_features,rotation=20)
plt.tight_layout()
plt.show()

# %%
# iris_forest.html_tree_summary()

# %% [markdown]
# Finally we can look at silhouette plots scores for various node encodings in order to get a feel for whether or not we are adequately clustering them and whether or not the clusters meaningfully exist.

# %%
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import linkage,dendrogram


sample_encoding = spherical_forest.node_representation(spherical_forest.nodes(depth=3,root=False),mode='sample')
reduced_sample = PCA(n_components=100).fit_transform(sample_encoding.T)
reduced_node = PCA(n_components=100).fit_transform(sample_encoding)

sample_agglomeration = dendrogram(linkage(reduced_sample, metric='cosine', method='average'), no_plot=True)['leaves']
node_agglomeration = dendrogram(linkage(reduced_node, metric='cosine', method='average'), no_plot=True)['leaves']

feature_encoding = spherical_forest.node_representation(spherical_forest.nodes(depth=3,root=False),mode='additive_mean')
reduced_feature = PCA().fit_transform(feature_encoding.T)
reduced_node = PCA().fit_transform(feature_encoding)

feature_agglomeration = dendrogram(linkage(reduced_feature, metric='cosine', method='average'), no_plot=True)['leaves']
node_agglomeration = dendrogram(linkage(reduced_node, metric='cosine', method='average'), no_plot=True)['leaves']

node_cluster_sort = np.argsort([n.split_cluster for n in spherical_forest.nodes(depth=3,root=False)])

# %%
# plt.figure()
# plt.title("Target Gain in Node (Gaussian Noise, Double-Agglomerated)")
# plt.imshow(feature_encoding[node_agglomeration].T[feature_agglomeration].T,cmap='bwr',interpolation='none',aspect='auto',vmin=-2,vmax=2)
# plt.xlabel("Features")
# plt.ylabel("Nodes")
# plt.colorbar(label="Parent Target Mean - Node Target Mean")
# plt.tight_layout()
# plt.show()

original_clusters = np.array([n.split_cluster for n in spherical_forest.nodes(depth=3,root=False)])
renumbered_clusters = original_clusters.copy()
renumbered_clusters[original_clusters == 1] = 3
renumbered_clusters[original_clusters == 2] = 4
renumbered_clusters[original_clusters == 3] = 1
renumbered_clusters[original_clusters == 4] = 2
sort_renumbered = np.argsort(renumbered_clusters)

plt.figure()
plt.title("Target Gain in Node (Gaussian Noise, Clustered)")
plt.imshow(feature_encoding[sort_renumbered].T[feature_agglomeration].T,cmap='bwr',interpolation='none',aspect='auto',vmin=-2,vmax=2)
plt.xlabel("Features")
plt.ylabel("Nodes")
plt.colorbar(label="Parent Target Mean - Node Target Mean")
plt.xticks([0,1,2,3],[1,2,3,4])
plt.tight_layout()
plt.show()

# %%
# Node mean encoding

mean_encoding = iris_forest.node_representation(iris_forest.nodes(depth=3,root=False),mode='mean')

node_agglomeration = dendrogram(linkage(mean_encoding, metric='cosine', method='average'), no_plot=True)['leaves']
mean_agglomeration = dendrogram(linkage(mean_encoding.T, metric='cosine', method='average'), no_plot=True)['leaves']

plt.figure()
plt.title("Figure S2 a: Target Mean in Node (Gaussian Noise, Double-Agglomerated)")
plt.imshow(mean_encoding[node_agglomeration].T[mean_agglomeration].T,cmap='viridis',interpolation='none',aspect='auto')
plt.xlabel("Features")
plt.ylabel("Nodes")
plt.colorbar(label="Parent Target Mean - Node Target Mean")
plt.tight_layout()
plt.show()

# %%
# Silhouette Plots For Node Clusters 

from sklearn.metrics import silhouette_samples, silhouette_score

# feature_encoding = iris_forest.node_representation(iris_forest.nodes(depth=3,root=False),mode='additive_mean')
# node_labels = np.array([n.split_cluster for n in iris_forest.nodes(depth=3,root=False)])

feature_encoding = spherical_forest.node_representation(spherical_forest.nodes(depth=3,root=False),mode='additive_mean')
node_labels = np.array([n.split_cluster for n in spherical_forest.nodes(depth=3,root=False)])

silhouette_scores = silhouette_samples(feature_encoding,node_labels,metric='cosine')

sorted_silhouette = np.zeros(silhouette_scores.shape)
sorted_colors = np.zeros(silhouette_scores.shape)
sorted_indices = []

current_index = 0
next_index = 0
for i in sorted(set(node_labels)):
    mask = node_labels == i
#     selected_values = sorted(silhouette_scores[mask])    
    value_sort = np.argsort(silhouette_scores[mask])
    selected_values = silhouette_scores[mask][value_sort]
    sorted_local_indices = np.arange(len(silhouette_scores))[mask][value_sort]
    sorted_indices.extend(sorted_local_indices)
    next_index = current_index + np.sum(mask)
    sorted_silhouette[current_index:next_index] = selected_values
    sorted_colors[current_index:next_index] = i
    current_index = next_index

# %%
import matplotlib.cm as cm

plt.figure()
plt.title("Silhouette Plots For Node-Gain Encodings \n Clustered By Gain")
for i,node in enumerate(sorted_silhouette):
    plt.plot([0,node],[i,i],color=cm.nipy_spectral(sorted_colors[i] / len(iris_forest.split_clusters)))
# plt.scatter(sorted_silhouette,np.arange(len(sorted_silhouette)),s=1)
plt.plot([0,0],[0,len(sorted_silhouette)],color='black')
plt.xlabel("Silhouette Score")
plt.ylabel("Nodes")
plt.show()

# %%
plt.figure()
plt.title("Figure S2 b: Target Gain in Node (Clustered)")
plt.imshow(feature_encoding[sorted_indices].T[feature_agglomeration].T,cmap='bwr',interpolation='none',aspect='auto',vmin=-2,vmax=2)
plt.xlabel("Features")
plt.ylabel("Nodes")
plt.colorbar(label="Parent Target Mean - Node Target Mean")
plt.tight_layout()
plt.show()

# %%
# Sample silhouettes 


from sklearn.metrics import silhouette_samples, silhouette_score

sample_encoding = iris_forest.node_representation(iris_forest.nodes(depth=3,root=False),mode='sister')
node_labels = np.array([n.split_cluster for n in iris_forest.nodes(depth=3,root=False)])

# sample_encoding = spherical_forest.node_representation(spherical_forest.nodes(depth=3,root=False),mode='sister')
# node_labels = np.array([n.split_cluster for n in spherical_forest.nodes(depth=3,root=False)])

silhouette_scores = silhouette_samples(sample_encoding,node_labels,metric='cosine')

sorted_silhouette = np.zeros(silhouette_scores.shape)
sorted_colors = np.zeros(silhouette_scores.shape)
sorted_indices = []

current_index = 0
next_index = 0
for i in sorted(set(node_labels)):
    mask = node_labels == i
    value_sort = np.argsort(silhouette_scores[mask])
    selected_values = silhouette_scores[mask][value_sort]
    sorted_local_indices = np.arange(len(silhouette_scores))[mask][value_sort]
    sorted_indices.extend(sorted_local_indices)
    next_index = current_index + np.sum(mask)
    sorted_silhouette[current_index:next_index] = selected_values
    sorted_colors[current_index:next_index] = i
    current_index = next_index

# %%
import matplotlib.cm as cm

plt.figure()
plt.title("Silhouette Plots For Node-Sister Encodings \n Clustered By Gain")
for i,node in enumerate(sorted_silhouette):
    plt.plot([0,node],[i,i],color=cm.nipy_spectral(sorted_colors[i] / len(iris_forest.split_clusters)))
# plt.scatter(sorted_silhouette,np.arange(len(sorted_silhouette)),s=1)
plt.plot([0,0],[0,len(sorted_silhouette)],color='black')
plt.ylim(1180,0)
plt.xlabel("Silhouette Score")
plt.ylabel("Nodes")
plt.show()

# %%
plt.figure()
plt.title("Figure S2 b: Target Gain in Node (Clustered)")
plt.imshow(sample_encoding[sorted_indices].T[sample_agglomeration].T,cmap='bwr',interpolation='none',aspect='auto')
plt.xlabel("Features")
plt.ylabel("Nodes")
plt.colorbar(label="Parent Target Mean - Node Target Mean")
plt.tight_layout()
plt.show()

# %%
sample_encoding.shape

# %%
sorted_indices

# %%
list(silhouette_scores[sorted_indices])

# %%
pa = iris_forest.node_representation(iris_forest.nodes(),mode='partial_absolute')

# %%
np.sum(np.abs(pa),axis=0)

# %%
[r.index for r in iris_forest.roots()]

# %%
pa[899]

# %%
np.around(iris_forest.node_representation(iris_forest.trees[0].nodes(),mode='partial_absolute'),3)
# Out:
# Node 0
# array([[0.015, 0.045, 0.   , 0.   ],
#        [0.098, 0.293, 0.   , 0.002],
#        [0.003, 0.035, 0.019, 0.017],
#        [0.047, 0.522, 0.285, 0.255],
#        [0.023, 0.008, 0.009, 0.027],
#        [0.13 , 0.043, 0.052, 0.154],
#        [0.44 , 0.035, 0.409, 0.351],
#        [0.243, 0.019, 0.226, 0.194],
#        [0.   , 0.   , 0.   , 0.   ]])

# %%
iris_forest.trees[0].root.nodes()[-1].level
